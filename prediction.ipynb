# %%
import pandas as pd

# %%
df = pd.read_excel('weight_price.xlsx')
df.head()
# Out:
#    WEIGHT  PRICE
# 0       2     35
# 1       4     60
# 2       5     20
# 3       3     50
# 4       6     50

# %%
df.tail()
# Out:
#    WEIGHT  PRICE
# 2       5     20
# 3       3     50
# 4       6     50
# 5       5     55
# 6       7     60

# %%
df.shape
# Out:
# (7, 2)

# %%
df.describe()
# Out:
#          WEIGHT      PRICE
# count  7.000000   7.000000
# mean   4.571429  47.142857
# std    1.718249  14.679107
# min    2.000000  20.000000
# 25%    3.500000  42.500000
# 50%    5.000000  50.000000
# 75%    5.500000  57.500000
# max    7.000000  60.000000

# %%
df.isnull().sum()
# Out:
# WEIGHT    0
# PRICE     0
# dtype: int64

# %% [markdown]
# TASK 1

# %%
x=df['WEIGHT']
y=df['PRICE']

# %%
import numpy as np

# %%
mean_x = np.mean(x)
mean_y = np.mean(y)

# %%
mean_x
# Out:
# 4.571428571428571

# %%
mean_y
# Out:
# 47.142857142857146

# %%
dev_x= x -mean_x
dev_y=y-mean_y

# %%
m = np.sum(dev_x*dev_y)/np.sum(dev_x**2)

# %%
m
# Out:
# 2.620967741935484

# %%
c = mean_y -(m*mean_x)

# %%
c
# Out:
# 35.16129032258065

# %%
(m*6.5)+c
# Out:
# 52.197580645161295

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(df[['WEIGHT']],df[['PRICE']])
# Out:
# LinearRegression()

# %%
reg.predict([[6.5]])
# Out:
# D:\SOFT\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[52.19758065]])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.WEIGHT,df.PRICE)
plt.xlabel('WIGHT')
plt.ylabel('PRICE')
# Out:
# Text(0, 0.5, 'PRICE')

# %%
df2=df.copy()
df.head()
# Out:
#    WEIGHT  PRICE
# 0       2     35
# 1       4     60
# 2       5     20
# 3       3     50
# 4       6     50

# %%
df2['Prediction_price']=reg.predict(df[['WEIGHT']])
df2.head()
# Out:
#    WEIGHT  PRICE  Prediction_price
# 0       2     35         40.403226
# 1       4     60         45.645161
# 2       5     20         48.266129
# 3       3     50         43.024194
# 4       6     50         50.887097

# %% [markdown]
# TASK 2

# %%
df2['res']=df2['PRICE']-df2['Prediction_price']
df2.head()
# Out:
#    WEIGHT  PRICE  Prediction_price        res
# 0       2     35         40.403226  -5.403226
# 1       4     60         45.645161  14.354839
# 2       5     20         48.266129 -28.266129
# 3       3     50         43.024194   6.975806
# 4       6     50         50.887097  -0.887097

# %%
reg.score(df[['WEIGHT']],df[['PRICE']])
# Out:
# 0.09412315095348434

# %% [markdown]
# Task=3

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse= mean_squared_error(df2[['Prediction_price']],df2[['PRICE']])

# %%
mse
# Out:
# 167.30990783410135

# %%
mae=mean_absolute_error(df2[['Prediction_price']],df2[['PRICE']])

# %%
mae
# Out:
# 9.87327188940092
